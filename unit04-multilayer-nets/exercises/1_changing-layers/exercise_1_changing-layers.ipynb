# %% [markdown]
# # Implementing a Multilayer Perceptron (MNIST)

# %% [markdown]
# ## 1) Installing Libraries

# %%
# !conda install numpy pandas matplotlib --yes

# %%
# !pip install torch torchvision torchaudio

# %%
# !conda install watermark

# %%
# %load_ext watermark
# %watermark -v -p numpy,pandas,matplotlib,torch
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.9.18
# IPython version      : 8.18.1
#
# numpy     : 2.0.2
# pandas    : 2.2.3
# matplotlib: 3.9.4
# torch     : 2.6.0+cu126

# %% [markdown]
# ## 2) Loading the dataset

# %% [markdown]
# - MNIST website: http://yann.lecun.com/exdb/mnist/

# %%
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

train_dataset = datasets.MNIST(
    root="./mnist", train=True, transform=transforms.ToTensor(), download=True
)

test_dataset = datasets.MNIST(
    root="./mnist", train=False, transform=transforms.ToTensor()
)

# %%
len(train_dataset)
# Out:
# 60000

# %%
len(test_dataset)
# Out:
# 10000

# %% [markdown]
# ### Create a validation set

# %%
import torch
from torch.utils.data.dataset import random_split

torch.manual_seed(1)
train_dataset, val_dataset = random_split(train_dataset, lengths=[55000, 5000])

# %%
train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=64,
    shuffle=True,
)

val_loader = DataLoader(
    dataset=val_dataset,
    batch_size=64,
    shuffle=False,
)

test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=64,
    shuffle=False,
)

# %% [markdown]
# ## 3) Implementing the model

# %%
import torch

class PyTorchMLP(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super().__init__()

        self.all_layers = torch.nn.Sequential(
            # 1st hidden layer
            torch.nn.Linear(num_features, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, 16),
            torch.nn.ReLU(),
            torch.nn.Linear(16, 8),
            torch.nn.ReLU(),
            # output layer
            torch.nn.Linear(8, num_classes),
        )

    def forward(self, x):
        x = torch.flatten(x, start_dim=1)
        logits = self.all_layers(x)
        return logits

# %% [markdown]
# ## 4) The training loop

# %%
def compute_accuracy(model, dataloader):

    model = model.eval()

    correct = 0.0
    total_examples = 0

    for idx, (features, labels) in enumerate(dataloader):

        with torch.no_grad():
            logits = model(features)

        predictions = torch.argmax(logits, dim=1)

        compare = labels == predictions
        correct += torch.sum(compare)
        total_examples += len(compare)

    return correct / total_examples

# %%
import torch.nn.functional as F

torch.manual_seed(1)
model = PyTorchMLP(num_features=784, num_classes=10)

optimizer = torch.optim.SGD(model.parameters(), lr=0.05)

num_epochs = 10

loss_list = []
train_acc_list, val_acc_list = [], []
for epoch in range(num_epochs):

    model = model.train()
    for batch_idx, (features, labels) in enumerate(train_loader):

        logits = model(features)

        loss = F.cross_entropy(logits, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if not batch_idx % 250:
            ### LOGGING
            print(
                f"Epoch: {epoch+1:03d}/{num_epochs:03d}"
                f" | Batch {batch_idx:03d}/{len(train_loader):03d}"
                f" | Train Loss: {loss:.2f}"
            )
        loss_list.append(loss.item())

    train_acc = compute_accuracy(model, train_loader)
    val_acc = compute_accuracy(model, val_loader)
    print(f"Train Acc {train_acc*100:.2f}% | Val Acc {val_acc*100:.2f}%")
    train_acc_list.append(train_acc)
    val_acc_list.append(val_acc)
# Out:
# Epoch: 001/010 | Batch 000/860 | Train Loss: 2.36
# Epoch: 001/010 | Batch 250/860 | Train Loss: 1.76
# Epoch: 001/010 | Batch 500/860 | Train Loss: 0.69
# Epoch: 001/010 | Batch 750/860 | Train Loss: 0.58
# Train Acc 84.16% | Val Acc 84.32%
# Epoch: 002/010 | Batch 000/860 | Train Loss: 0.72
# Epoch: 002/010 | Batch 250/860 | Train Loss: 0.35
# Epoch: 002/010 | Batch 500/860 | Train Loss: 0.37
# Epoch: 002/010 | Batch 750/860 | Train Loss: 0.16
# Train Acc 90.05% | Val Acc 89.72%
# Epoch: 003/010 | Batch 000/860 | Train Loss: 0.43
# Epoch: 003/010 | Batch 250/860 | Train Loss: 0.17
# Epoch: 003/010 | Batch 500/860 | Train Loss: 0.11
# Epoch: 003/010 | Batch 750/860 | Train Loss: 0.19
# Train Acc 93.69% | Val Acc 93.02%
# Epoch: 004/010 | Batch 000/860 | Train Loss: 0.27
# Epoch: 004/010 | Batch 250/860 | Train Loss: 0.39
# Epoch: 004/010 | Batch 500/860 | Train Loss: 0.24
# Epoch: 004/010 | Batch 750/860 | Train Loss: 0.21
# Train Acc 95.08% | Val Acc 93.94%
# Epoch: 005/010 | Batch 000/860 | Train Loss: 0.24
# Epoch: 005/010 | Batch 250/860 | Train Loss: 0.06
# Epoch: 005/010 | Batch 500/860 | Train Loss: 0.35
# Epoch: 005/010 | Batch 750/860 | Train Loss: 0.18
# Train Acc 95.41% | Val Acc 94.68%
# Epoch: 006/010 | Batch 000/860 | Train Loss: 0.15
# Epoch: 006/010 | Batch 250/860 | Train Loss: 0.22
# Epoch: 006/010 | Batch 500/860 | Train Loss: 0.31
# Epoch: 006/010 | Batch 750/860 | Train Loss: 0.21
# Train Acc 96.37% | Val Acc 94.80%
# Epoch: 007/010 | Batch 000/860 | Train Loss: 0.15
# Epoch: 007/010 | Batch 250/860 | Train Loss: 0.20
# Epoch: 007/010 | Batch 500/860 | Train Loss: 0.06
# Epoch: 007/010 | Batch 750/860 | Train Loss: 0.12
# Train Acc 96.73% | Val Acc 95.32%
# Epoch: 008/010 | Batch 000/860 | Train Loss: 0.08
# Epoch: 008/010 | Batch 250/860 | Train Loss: 0.08
# Epoch: 008/010 | Batch 500/860 | Train Loss: 0.05
# Epoch: 008/010 | Batch 750/860 | Train Loss: 0.01
# Train Acc 96.39% | Val Acc 94.72%
# Epoch: 009/010 | Batch 000/860 | Train Loss: 0.19
# Epoch: 009/010 | Batch 250/860 | Train Loss: 0.07
# Epoch: 009/010 | Batch 500/860 | Train Loss: 0.08
# Epoch: 009/010 | Batch 750/860 | Train Loss: 0.13
# Train Acc 97.05% | Val Acc 95.52%
# Epoch: 010/010 | Batch 000/860 | Train Loss: 0.17
# Epoch: 010/010 | Batch 250/860 | Train Loss: 0.09
# Epoch: 010/010 | Batch 500/860 | Train Loss: 0.05
# Epoch: 010/010 | Batch 750/860 | Train Loss: 0.25
# Train Acc 96.75% | Val Acc 95.40%

# %% [markdown]
# ## 7) Evaluating the results

# %%
train_acc = compute_accuracy(model, train_loader)
val_acc = compute_accuracy(model, val_loader)
test_acc = compute_accuracy(model, test_loader)

print(f"Train Acc {train_acc*100:.2f}%")
print(f"Val Acc {val_acc*100:.2f}%")
print(f"Test Acc {test_acc*100:.2f}%")
# Out:
# Train Acc 96.75%
# Val Acc 95.40%
# Test Acc 95.44%

# %%
from helper_plotting import plot_training_loss

plot_training_loss(minibatch_loss_list=loss_list,
                   num_epochs=num_epochs,
                   iter_per_epoch=len(loss_list)//num_epochs)

# %%
from helper_plotting import plot_accuracy

plot_accuracy(train_acc_list=train_acc_list, valid_acc_list=val_acc_list)
